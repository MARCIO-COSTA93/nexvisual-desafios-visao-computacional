# %% [markdown]
# ## Desafio 3 da Trilha de Visão Computacional
#
# Nesse desafio você irá implementar uma solução simples para realizar o rastreamento de objetos.
#
# Para isso você deverá seguir os pasos desse documento atentamente.

# %% [markdown]
# ### Instalação e Importação da Biblioteca

# %%
# !pip install ultralytics opencv-python torch
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\moliv\AppData\Local\Programs\Python\Python313\Scripts\pip.exe\__main__.py", line 2, in <module>
#   File "C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages\pip\_internal\__init__.py", line 3, in <module>
#     from pip._internal.utils import _log
#   File "C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages\pip\_internal\utils\_log.py", line 8, in <module>
#     import logging
#   File "C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\logging\__init__.py", line 26, in <module>
#     import sys, os, time, io, re, traceback, warnings, weakref, collections.abc
#   File "C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\traceback.py", line 8, in <module>
#     import warnings
#   File "C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\warnings.py", line 15, in <module>
#     from _py_warnings import (
#   File "C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\_py_warnings.py", line 49, in <module>
#     _use_context = sys.flags.context_aware_warnings
# AttributeError: 'sys.flags' object has no attribute 'context_aware_warnings'

# %%
import sys
# !{sys.executable} -m pip install ultralytics opencv-python torch --break-system-packages
# Out:
# Requirement already satisfied: ultralytics in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (8.4.60)
# Requirement already satisfied: opencv-python in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (4.13.0.92)
# Requirement already satisfied: torch in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (2.12.0)
# Requirement already satisfied: numpy>=1.23.0 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from ultralytics) (2.4.6)
# Requirement already satisfied: matplotlib>=3.3.0 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from ultralytics) (3.10.9)
# Requirement already satisfied: pillow>=7.1.2 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from ultralytics) (12.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from ultralytics) (2.34.2)
# Requirement already satisfied: scipy>=1.4.1 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from ultralytics) (1.17.1)
# Requirement already satisfied: torchvision>=0.9.0 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from ultralytics) (0.27.0)
# Requirement already satisfied: psutil>=5.8.0 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from ultralytics) (1.41.2)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from ultralytics) (2.0.19)
# Requirement already satisfied: filelock in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from torch) (3.29.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from torch) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from torch) (2026.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=3 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.41.2 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from polars>=0.20.0->ultralytics) (1.41.2)
# Requirement already satisfied: six>=1.5 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from requests>=2.23.0->ultralytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from requests>=2.23.0->ultralytics) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from requests>=2.23.0->ultralytics) (2026.5.20)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages (from jinja2->torch) (3.0.3)

# %%
import ultralytics
import cv2
import torch

# %% [markdown]
# ### Processar dados

# %%
# Baixa o modelo
model = ultralytics.YOLO("yolo11n.pt") 

# Jogao o modelo para o dispositivo de computação
device = "cuda" if torch.cuda.is_available() else "cpu"
model = model.to(device)

# processa o vídeo
results = model.track(source="video.mov", conf=0.1, iou=0.7)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 9
#       5 device = "cuda" if torch.cuda.is_available() else "cpu"
#       6 model = model.to(device)
#       7
#       8 # processa o vídeo
# ----> 9 results = model.track(source="video.mov", conf=0.1, iou=0.7)
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages\ultralytics\engine\model.py:580, in Model.track(self, source, stream, persist, **kwargs)
#     578 kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     579 kwargs["mode"] = "track"
# --> 580 return self.predict(source=source, stream=stream, **kwargs)
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages\ultralytics\engine\model.py:537, in Model.predict(self, source, stream, predictor, **kwargs)
#     535 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     536     self.predictor.set_prompts(prompts)
# --> 537 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages\ultralytics\engine\predictor.py:228, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     226     return self.stream_inference(source, model, *args, **kwargs)
#     227 else:
# --> 228     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages\torch\utils\_contextlib.py:40, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      37 try:
#      38     # Issuing `None` to a generator fires it up
#      39     with ctx_factory():
# ---> 40         response = gen.send(None)
#      42     while True:
#      43         try:
#      44             # Forward the response to our caller and get its next request
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages\ultralytics\engine\predictor.py:302, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     298     self.setup_model(model)
#     300 with self._lock:  # for thread-safe inference
#     301     # Setup source every time predict is called
# --> 302     self.setup_source(source if source is not None else self.args.source)
#     304     # Check if save_dir/ label file exists
#     305     if self.args.save or self.args.save_txt:
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages\ultralytics\engine\predictor.py:259, in BasePredictor.setup_source(self, source, stride)
#     251 """Set up source and inference mode.
#     252
#     253 Args:
#    (...)    256     stride (int, optional): Model stride for image size checking.
#     257 """
#     258 self.imgsz = check_imgsz(self.args.imgsz, stride=stride or self.model.stride, min_dim=2)  # check image size
# --> 259 self.dataset = load_inference_source(
#     260     source=source,
#     261     batch=self.args.batch,
#     262     vid_stride=self.args.vid_stride,
#     263     buffer=self.args.stream_buffer,
#     264     channels=getattr(self.model, "channels", 3),
#     265 )
#     266 self.source_type = self.dataset.source_type
#     267 if (
#     268     self.source_type.stream
#     269     or self.source_type.screenshot
#     270     or len(self.dataset) > 1000  # many images
#     271     or any(getattr(self.dataset, "video_flag", [False]))
#     272 ):  # long sequence
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages\ultralytics\data\build.py:456, in load_inference_source(source, batch, vid_stride, buffer, channels)
#     454     dataset = LoadPilAndNumpy(source, channels=channels)
#     455 else:
# --> 456     dataset = LoadImagesAndVideos(source, batch=batch, vid_stride=vid_stride, channels=channels)
#     458 # Attach source types to the dataset
#     459 setattr(dataset, "source_type", source_type)
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages\ultralytics\data\loaders.py:368, in LoadImagesAndVideos.__init__(self, path, batch, vid_stride, channels)
#     366         files.append(str((parent / p).absolute()))  # files (relative to *.txt file parent)
#     367     else:
# --> 368         raise FileNotFoundError(f"{p} does not exist")
#     370 # Define files as images or videos
#     371 images, videos = [], []
#
# FileNotFoundError: video.mov does not exist

# %% [markdown]
# ### Salvar Vídeo

# %%
# validar resultados
for r in results:
    print(r)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # validar resultados
# ----> 2 for r in results:
#       3     print(r)
#
# NameError: name 'results' is not defined

# %%
# Cria o escritor do vídeo de output
# Você pode pesquisar para salvar em outros formatos
writer  = cv2.VideoWriter("output.avi", cv2.VideoWriter_fourcc(*"XVID"), 20, (2048, 1080))

# Escreve o vídeo de output
for r in results:
    writer.write(r.plot())

# %% [markdown]
# ### Referência
#
# - https://docs.ultralytics.com/modes/track/
