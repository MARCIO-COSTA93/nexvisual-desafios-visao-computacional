# %% [markdown]
# ## Desafio 4 da Trilha de Visão Computacional
#
# Nesse desafio você irá implementar uma solução simples para reconhecimento de poses, muito útil em análises esportivas por exemplo.
#
# Para isso você deverá seguir os pasos desse documento atentamente.

# %% [markdown]
# ### Instalação e Importação da Biblioteca

# %%
# !pip install ultralytics matplotlib torch
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\moliv\AppData\Local\Programs\Python\Python313\Scripts\pip.exe\__main__.py", line 2, in <module>
#   File "C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages\pip\_internal\__init__.py", line 3, in <module>
#     from pip._internal.utils import _log
#   File "C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\site-packages\pip\_internal\utils\_log.py", line 8, in <module>
#     import logging
#   File "C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\logging\__init__.py", line 26, in <module>
#     import sys, os, time, io, re, traceback, warnings, weakref, collections.abc
#   File "C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\traceback.py", line 8, in <module>
#     import warnings
#   File "C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\warnings.py", line 15, in <module>
#     from _py_warnings import (
#   File "C:\Users\moliv\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\_py_warnings.py", line 49, in <module>
#     _use_context = sys.flags.context_aware_warnings
# AttributeError: 'sys.flags' object has no attribute 'context_aware_warnings'

# %%
import ultralytics
import matplotlib.pyplot as plt
import torch

# %% [markdown]
# ### Processar Dados

# %%
# Baixa o modelo de pose da YOLO.
model = ultralytics.YOLO("yolo11n-pose.pt")

device = "cuda" if torch.cuda.is_available() else "cpu"
model = model.to(device)

# Processa a imagem.
# TODO testar outras imagens.
results = model("desafio_4.jpeg")  # predict on an image
# Out:
# image 1/1 c:\Users\moliv\Downloads\OneDrive_4_1-26-2026\VC_Desafio_4\desafio_4_pose_estimation\desafio_4.jpeg: 288x640 5 persons, 181.7ms
# Speed: 10.7ms preprocess, 181.7ms inference, 16.0ms postprocess per image at shape (1, 3, 288, 640)

# %% [markdown]
# ### Visualizar Resultados

# %%
from PIL import Image
import cv2

print(results[0])

# Gera visualização do resultado
im_array = results[0].plot()
rgb_img = cv2.cvtColor(im_array, cv2.COLOR_BGR2RGB)



# Visualize a imagem rgb_img
plt.imshow(rgb_img)
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: ultralytics.engine.results.Keypoints object
# masks: None
# names: {0: 'person'}
# obb: None
# orig_img: array([[[119, 140, 131],
#         [118, 139, 130],
#         [120, 139, 130],
#         ...,
#         [183, 220, 204],
#         [194, 228, 211],
#         [223, 246, 231]],
#
#        [[120, 139, 130],
#         [118, 137, 128],
#         [118, 137, 128],
#         ...,
#         [200, 233, 219],
#         [190, 226, 210],
#         [199, 228, 212]],
#
#        [[118, 137, 128],
#         [117, 136, 127],
#         [117, 136, 127],
#         ...,
#         [219, 247, 241],
#         [204, 236, 225],
#         [201, 227, 213]],
#
#        ...,
#
#        [[113, 134, 165],
#         [113, 134, 162],
#         [ 98, 115, 141],
#         ...,
#         [128, 121,  58],
#         [128, 124,  59],
#         [118, 115,  47]],
#
#        [[107, 128, 159],
#         [102, 123, 151],
#         [ 98, 115, 141],
#         ...,
#         [116, 107,  44],
#         [127, 120,  57],
#         [128, 124,  59]],
#
#        [[ 87, 107, 138],
#         [ 79,  98, 125],
#         [ 80,  97, 123],
#         ...,
#         [107,  97,  37],
#         [120, 111,  48],
#         [125, 119,  54]]], shape=(2691, 6000, 3), dtype=uint8)
# orig_shape: (2691, 6000)
# path: 'c:\\Users\\moliv\\Downloads\\OneDrive_4_1-26-2026\\VC_Desafio_4\\desafio_4_pose_estimation\\desafio_4.jpeg'
# probs: None
# save_dir: 'C:\\Users\\moliv\\runs\\pose\\predict'
# semantic_mask: None
# speed: {'preprocess': 10.723499988671392, 'inference': 181.69259998830967, 'postprocess': 16.0193000047002}

# %% [markdown]
# ### Referência
#
# - https://docs.ultralytics.com/tasks/pose
